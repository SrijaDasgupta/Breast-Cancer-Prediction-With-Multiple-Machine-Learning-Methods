# %% [markdown]
# <a href="https://colab.research.google.com/github/SrijaDasgupta/Breast-Cancer-Prediction-With-Multiple-Machine-Learning-Methods/blob/main/FINAL_PROJECT_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Conv1D, MaxPool1D, GlobalAveragePooling1D
from sklearn import preprocessing
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from keras.layers import LeakyReLU

## GOLOBAL VARIABLES ##

dataset_dir = '/content/drive/MyDrive/data.csv'

# %%
class dataset():
    def __init__(self):
        self.data = pd.read_csv(dataset_dir)
        # self.data.drop(['id'],axis=1,inplace=True)

    # define a function to do label encoding
    def label_encoding(self):
        le = preprocessing.LabelEncoder()
        self.data['diagnosis'] = le.fit_transform(self.data['diagnosis'])
        return self.data
    # Define a function to prepare X and Y out of the data

    def prepare_data(self):
        self.data = self.label_encoding()
        self.X = self.data.drop(columns=['diagnosis', 'id', 'Unnamed: 32'], axis=1)
        self.Y = self.data['diagnosis']
        return self.X, self.Y
    # Define a function to split the data into train and test, standard scalar them, and reshape them to fit the CNN

    def data_preparation(self):
        self.X, self.Y = self.prepare_data()
        self.X_train, self.X_test, self.Y_train, self.Y_test = train_test_split(self.X, self.Y, test_size=0.2, random_state=42)
        self.scaler = StandardScaler()
        self.X_train = self.scaler.fit_transform(self.X_train)
        self.X_test = self.scaler.transform(self.X_test)
        self.X_train = self.X_train.reshape(self.X_train.shape[0], self.X_train.shape[1], 1)
        self.X_test = self.X_test.reshape(self.X_test.shape[0], self.X_test.shape[1], 1)
        return self.X_train, self.X_test, self.Y_train, self.Y_test
###############################
# Define the CNN model: we are going to define a CNN model with the following architecture:
# 1. Convolutional layer with 32 filters and a kernel size of 3
# 2. Using Leaky Relu activation function is better than Relu on the output of the convolutional layer
# 3. Using L1 regularization of factor 0.01 applied to the kernel matrix, since the input is features
# and L1 regularization is a way of feature selection
# 4. Batch Normalization
# 5 . Dropout


class CNN():
    def __init__(self, X_train, X_test, Y_train, Y_test):
        self.X_train = X_train
        self.X_test = X_test
        self.Y_train = Y_train
        self.Y_test = Y_test
        self.model = Sequential()

    def model_architecture(self):
        self.model.add(Conv1D(32, 2, input_shape=(30, 1), kernel_regularizer=keras.regularizers.l1(0.01), kernel_initializer='HeNormal'))
        self.model.add(LeakyReLU(alpha=0.01))
        self.model.add(BatchNormalization())
        self.model.add(Dropout(0.2))
        self.model.add(MaxPool1D(pool_size=2, padding='same'))
        self.model.add(Conv1D(64, 2, kernel_regularizer=keras.regularizers.l1(0.01), kernel_initializer='HeNormal'))
        self.model.add(LeakyReLU(alpha=0.01))
        self.model.add(BatchNormalization())
        self.model.add(Dropout(0.2))
        self.model.add(MaxPool1D(pool_size=2, padding='same'))
        self.model.add(Conv1D(128, 2, kernel_regularizer=keras.regularizers.l1(0.01), kernel_initializer='HeNormal'))
        self.model.add(LeakyReLU(alpha=0.01))
        self.model.add(BatchNormalization())
        self.model.add(Dropout(0.2))
        self.model.add(Conv1D(256, 2, kernel_regularizer=keras.regularizers.l1(0.01), kernel_initializer='HeNormal'))
        self.model.add(LeakyReLU(alpha=0.01))
        self.model.add(BatchNormalization())
        self.model.add(Dropout(0.2))
        self.model.add(GlobalAveragePooling1D())
        self.model.add(Dense(128))
        self.model.add(LeakyReLU(alpha=0.01))
        self.model.add(Dropout(0.2))
        self.model.add(Dense(32))
        self.model.add(Dense(1, activation='sigmoid'))
        return self.model


    def plot_history_accuracy(self, history):
        fig, axs = plt.subplots(1, 2, figsize=(15, 5))
        axs[0].plot(history.history['accuracy'], label='accuracy')
        axs[0].plot(history.history['val_accuracy'], label='val_accuracy')
        axs[0].set_ylabel('Accuracy')
        axs[0].set_xlabel('Epoch')
        axs[0].set_title('Model Accuracy')
        axs[0].legend(loc='lower right')
        axs[1].plot(history.history['loss'], label='loss')
        axs[1].plot(history.history['val_loss'], label='val_loss')
        axs[1].set_ylabel('Loss')
        axs[1].set_xlabel('Epoch')
        axs[1].set_title('Model Loss')
        axs[1].legend(loc='upper right')
        plt.tight_layout()
        plt.show()

    # Define a function to train the model

    def train_evaluation_model(self, BATCH_SIZE=32, EPOCHS=50):
        self.model = self.model_architecture()
        self.model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])
        
        # REDUCE LEARNING RATE ON PLATEU
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=0.8, patience=6, min_lr=0.00001, verbose=1)
        # fit the model:
        history = self.model.fit(self.X_train, self.Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=(self.X_test, self.Y_test), verbose=1)
        # self.plot_history(history)
        self.plot_history_accuracy(history)
        predict_labels = (self.model.predict(self.X_test) > 0.5).astype(np.int32)
        print(classification_report(self.Y_test, predict_labels))
        ###
        print("Accuracy on the test Step:", accuracy_score(self.Y_test, predict_labels))
        # show confusion matrix
        conf_matrix = confusion_matrix(self.Y_test, predict_labels)
        sns.heatmap(conf_matrix, annot=True, fmt="d", cbar=False, xticklabels=['benign', 'malignant'], yticklabels=['benign', 'malignant'])

    # Define a function to evaluate the model

    # def evaluate_model(self):
    #     self.model1 = self.model_architecture()
    #     self.model1.load_weights(SAVE_MODEL_DIR)
    #     predict_labels = (self.model1.predict(self.X_test) > 0.5).astype(np.int)
    #     print(classification_report(self.Y_test, predict_labels))
    #     ###
    #     print("Accuracy on the test Step:", accuracy_score(self.Y_test, predict_labels))
    #     # show confusion matrix
    #     conf_matrix = confusion_matrix(self.Y_test, predict_labels)
    #     sns.heatmap(conf_matrix, annot=True, fmt="d", cbar=False, xticklabels=['benign', 'malignant'], yticklabels=['benign', 'malignant'])

# %%
def main():
    # Initialize the dataset class
    dataset_obj = dataset()
    # Prepare the data
    X, Y = dataset_obj.prepare_data()
    print(X.shape, Y.shape)
    # Split the data into training and testing sets
    X_train, X_test, Y_train, Y_test = dataset_obj.data_preparation()
    # Initialize the CNN class
    cnn_obj = CNN(X_train, X_test, Y_train, Y_test)
    # Train the model
    cnn_obj.train_evaluation_model(BATCH_SIZE=12, EPOCHS=150)


if __name__ == '__main__':
    main()
# Out:
# (569, 30) (569,)
# Epoch 1/150
# 38/38 [==============================] - 3s 23ms/step - loss: 69.7969 - accuracy: 0.7231 - val_loss: 68.0617 - val_accuracy: 0.8158
# Epoch 2/150
# 38/38 [==============================] - 0s 12ms/step - loss: 66.4929 - accuracy: 0.8198 - val_loss: 64.8468 - val_accuracy: 0.9123
# Epoch 61/150
# 38/38 [==============================] - 1s 13ms/step - loss: 2.3207 - accuracy: 0.8725 - val_loss: 2.3988 - val_accuracy: 0.9211
# Epoch 62/150
# 38/38 [==============================] - 0s 12ms/step - loss: 2.3178 - accuracy: 0.8791 - val_loss: 2.0698 - val_accuracy: 0.9298
# Epoch 63/150
# 38/38 [==============================] - 0s 13ms/step - loss: 2.4675 - accuracy: 0.8615 - val_loss: 2.1303 - val_accuracy: 0.9386
# Epoch 64/150
# 38/38 [==============================] - 0s 12ms/step - loss: 2.0943 - accuracy: 0.8923 - val_loss: 2.0149 - val_accuracy: 0.8947
# Epoch 65/150
# 38/38 [==============================] - 0s 13ms/step - loss: 1.9792 - accuracy: 0.8769 - val_loss: 1.8641 - val_accuracy: 0.9649
# Epoch 66/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.8541 - accuracy: 0.8989 - val_loss: 1.8340 - val_accuracy: 0.9474
# Epoch 67/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.8632 - accuracy: 0.8747 - val_loss: 1.6700 - val_accuracy: 0.9649
# Epoch 68/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.7299 - accuracy: 0.8857 - val_loss: 1.6804 - val_accuracy: 0.9298
# Epoch 69/150
# 38/38 [==============================] - 1s 14ms/step - loss: 1.6886 - accuracy: 0.8835 - val_loss: 1.4786 - val_accuracy: 0.9649
# Epoch 70/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.6378 - accuracy: 0.8791 - val_loss: 1.3796 - val_accuracy: 0.9474
# Epoch 71/150
# 38/38 [==============================] - 0s 13ms/step - loss: 1.5507 - accuracy: 0.8769 - val_loss: 1.3479 - val_accuracy: 0.9649
# Epoch 72/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.5134 - accuracy: 0.8769 - val_loss: 1.4952 - val_accuracy: 0.9298
# Epoch 73/150
# 38/38 [==============================] - 0s 11ms/step - loss: 1.5213 - accuracy: 0.8813 - val_loss: 1.3114 - val_accuracy: 0.9561
# Epoch 74/150
# 38/38 [==============================] - 1s 13ms/step - loss: 1.4161 - accuracy: 0.8901 - val_loss: 1.3350 - val_accuracy: 0.9737
# Epoch 75/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.3706 - accuracy: 0.9033 - val_loss: 1.2448 - val_accuracy: 0.9561
# Epoch 76/150
# 38/38 [==============================] - 1s 13ms/step - loss: 1.3421 - accuracy: 0.8791 - val_loss: 1.7881 - val_accuracy: 0.4825
# Epoch 77/150
# 38/38 [==============================] - 0s 11ms/step - loss: 1.3448 - accuracy: 0.8791 - val_loss: 1.1183 - val_accuracy: 0.9737
# Epoch 78/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.2895 - accuracy: 0.8901 - val_loss: 1.1554 - val_accuracy: 0.9474
# Epoch 79/150
# 38/38 [==============================] - 0s 11ms/step - loss: 1.3566 - accuracy: 0.8791 - val_loss: 1.1178 - val_accuracy: 0.9649
# Epoch 80/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.2074 - accuracy: 0.8945 - val_loss: 1.0546 - val_accuracy: 0.9825
# Epoch 81/150
# 38/38 [==============================] - 0s 13ms/step - loss: 1.2006 - accuracy: 0.8989 - val_loss: 1.2180 - val_accuracy: 0.9123
# Epoch 82/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.2212 - accuracy: 0.8901 - val_loss: 1.1290 - val_accuracy: 0.9649
# Epoch 83/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.1367 - accuracy: 0.9055 - val_loss: 1.0652 - val_accuracy: 0.9474
# Epoch 84/150
# 38/38 [==============================] - 0s 13ms/step - loss: 1.1651 - accuracy: 0.9077 - val_loss: 1.1172 - val_accuracy: 0.9298
# Epoch 85/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.1745 - accuracy: 0.8967 - val_loss: 1.0324 - val_accuracy: 0.9649
# Epoch 86/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.1754 - accuracy: 0.9033 - val_loss: 1.0038 - val_accuracy: 0.9474
# Epoch 87/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.1420 - accuracy: 0.8945 - val_loss: 1.0269 - val_accuracy: 0.9298
# Epoch 88/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.0990 - accuracy: 0.9033 - val_loss: 0.9762 - val_accuracy: 0.9474
# Epoch 89/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.1199 - accuracy: 0.8989 - val_loss: 1.1745 - val_accuracy: 0.9123
# Epoch 90/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.2051 - accuracy: 0.8725 - val_loss: 0.9836 - val_accuracy: 0.9737
# Epoch 91/150
# 38/38 [==============================] - 0s 13ms/step - loss: 1.1098 - accuracy: 0.8835 - val_loss: 1.0762 - val_accuracy: 0.9649
# Epoch 92/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.0745 - accuracy: 0.8923 - val_loss: 0.8888 - val_accuracy: 0.9825
# Epoch 93/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.0640 - accuracy: 0.8901 - val_loss: 1.0244 - val_accuracy: 0.9474
# Epoch 94/150
# 38/38 [==============================] - 0s 11ms/step - loss: 1.0582 - accuracy: 0.8945 - val_loss: 0.9048 - val_accuracy: 0.9561
# Epoch 95/150
# 38/38 [==============================] - 0s 13ms/step - loss: 1.0016 - accuracy: 0.9253 - val_loss: 0.8832 - val_accuracy: 0.9386
# Epoch 96/150
# 38/38 [==============================] - 1s 14ms/step - loss: 0.9798 - accuracy: 0.9165 - val_loss: 0.9228 - val_accuracy: 0.9649
# Epoch 97/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.0574 - accuracy: 0.8901 - val_loss: 0.9175 - val_accuracy: 0.9561
# Epoch 98/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.0562 - accuracy: 0.8813 - val_loss: 1.0609 - val_accuracy: 0.8860
# Epoch 99/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.0422 - accuracy: 0.8879 - val_loss: 0.8508 - val_accuracy: 0.9737
# Epoch 100/150
# 38/38 [==============================] - 0s 13ms/step - loss: 1.0417 - accuracy: 0.8857 - val_loss: 0.8663 - val_accuracy: 0.9737
# Epoch 101/150
# 38/38 [==============================] - 0s 13ms/step - loss: 1.0566 - accuracy: 0.8835 - val_loss: 0.8681 - val_accuracy: 0.9737
# Epoch 102/150
# 38/38 [==============================] - 0s 12ms/step - loss: 0.9624 - accuracy: 0.9165 - val_loss: 0.8021 - val_accuracy: 0.9825
# Epoch 103/150
# 38/38 [==============================] - 0s 12ms/step - loss: 0.9236 - accuracy: 0.9121 - val_loss: 0.8229 - val_accuracy: 0.9649
# Epoch 104/150
# 38/38 [==============================] - 0s 13ms/step - loss: 0.9262 - accuracy: 0.9143 - val_loss: 0.8211 - val_accuracy: 0.9649
# Epoch 105/150
# 38/38 [==============================] - 1s 14ms/step - loss: 0.9777 - accuracy: 0.8945 - val_loss: 0.8415 - val_accuracy: 0.9649
# Epoch 106/150
# 38/38 [==============================] - 1s 14ms/step - loss: 1.0737 - accuracy: 0.8703 - val_loss: 1.0317 - val_accuracy: 0.9211
# Epoch 107/150
# 38/38 [==============================] - 0s 12ms/step - loss: 1.0347 - accuracy: 0.8791 - val_loss: 0.8840 - val_accuracy: 0.9561
# Epoch 108/150
# 38/38 [==============================] - 0s 11ms/step - loss: 0.9444 - accuracy: 0.9253 - val_loss: 0.8287 - val_accuracy: 0.9737
# Epoch 109/150
# 38/38 [==============================] - 0s 12ms/step - loss: 0.9972 - accuracy: 0.8879 - val_loss: 0.9004 - val_accuracy: 0.9474
# Epoch 110/150
# 38/38 [==============================] - 0s 12ms/step - loss: 0.9958 - accuracy: 0.8835 - val_loss: 0.8332 - val_accuracy: 0.9737
# Epoch 111/150
# 38/38 [==============================] - 1s 14ms/step - loss: 0.9917 - accuracy: 0.8945 - val_loss: 0.8977 - val_accuracy: 0.9298
# Epoch 112/150
# 38/38 [==============================] - 0s 12ms/step - loss: 0.9296 - accuracy: 0.9121 - val_loss: 0.8284 - val_accuracy: 0.9649
# Epoch 113/150
# 38/38 [==============================] - 0s 12ms/step - loss: 0.9656 - accuracy: 0.9011 - val_loss: 0.8200 - val_accuracy: 0.9561
# Epoch 114/150
# 38/38 [==============================] - 0s 12ms/step - loss: 0.9406 - accuracy: 0.8901 - val_loss: 0.9780 - val_accuracy: 0.9123
# Epoch 115/150
# 38/38 [==============================] - 1s 13ms/step - loss: 0.9845 - accuracy: 0.8945 - val_loss: 0.8885 - val_accuracy: 0.9298
# Epoch 116/150
# 38/38 [==============================] - 0s 12ms/step - loss: 0.9625 - accuracy: 0.8901 - val_loss: 0.8738 - val_accuracy: 0.9561
# Epoch 117/150
# 38/38 [==============================] - 0s 13ms/step - loss: 0.9434 - accuracy: 0.9033 - val_loss: 0.9494 - val_accuracy: 0.9298
# Epoch 118/150
# 38/38 [==============================] - 0s 11ms/step - loss: 0.9194 - accuracy: 0.9165 - val_loss: 0.7979 - val_accuracy: 0.9474
# Epoch 119/150
# 38/38 [==============================] - 0s 13ms/step - loss: 0.9241 - accuracy: 0.9011 - val_loss: 0.7977 - val_accuracy: 0.9649
# Epoch 120/150
# 38/38 [==============================] - 0s 13ms/step - loss: 0.8932 - accuracy: 0.9121 - val_loss: 0.7614 - val_accuracy: 0.9649
# Epoch 121/150
# 38/38 [==============================] - 0s 13ms/step - loss: 0.9305 - accuracy: 0.8945 - val_loss: 0.8213 - val_accuracy: 0.9561
# Epoch 122/150
# 38/38 [==============================] - 0s 12ms/step - loss: 0.9152 - accuracy: 0.8901 - val_loss: 0.8563 - val_accuracy: 0.9474
# Epoch 123/150
# 38/38 [==============================] - 0s 12ms/step - loss: 0.8996 - accuracy: 0.9077 - val_loss: 0.8108 - val_accuracy: 0.9649
# Epoch 124/150
# 38/38 [==============================] - 0s 13ms/step - loss: 0.9305 - accuracy: 0.8769 - val_loss: 1.0250 - val_accuracy: 0.8947
# Epoch 125/150
# 38/38 [==============================] - 1s 13ms/step - loss: 0.9204 - accuracy: 0.8901 - val_loss: 0.8053 - val_accuracy: 0.9474
# Epoch 126/150
# 38/38 [==============================] - 1s 13ms/step - loss: 0.9306 - accuracy: 0.8923 - val_loss: 0.8364 - val_accuracy: 0.9737
# Epoch 127/150
# 38/38 [==============================] - 0s 11ms/step - loss: 0.9202 - accuracy: 0.8967 - val_loss: 0.7940 - val_accuracy: 0.9386
# Epoch 128/150
# 38/38 [==============================] - 0s 12ms/step - loss: 0.8688 - accuracy: 0.9143 - val_loss: 0.7876 - val_accuracy: 0.9386
# Epoch 129/150
# 38/38 [==============================] - 0s 12ms/step - loss: 0.9097 - accuracy: 0.9055 - val_loss: 0.7658 - val_accuracy: 0.9737
# Epoch 130/150
# 38/38 [==============================] - 1s 14ms/step - loss: 0.9023 - accuracy: 0.9033 - val_loss: 0.8143 - val_accuracy: 0.9386
# Epoch 131/150
# 38/38 [==============================] - 0s 12ms/step - loss: 0.8682 - accuracy: 0.8989 - val_loss: 0.7299 - val_accuracy: 0.9737
# Epoch 132/150
# 38/38 [==============================] - 0s 11ms/step - loss: 0.9057 - accuracy: 0.8923 - val_loss: 0.7472 - val_accuracy: 0.9825
# Epoch 133/150
# 38/38 [==============================] - 0s 11ms/step - loss: 0.8670 - accuracy: 0.9165 - val_loss: 0.7799 - val_accuracy: 0.9474
# Epoch 134/150
# 38/38 [==============================] - 1s 13ms/step - loss: 0.8498 - accuracy: 0.9165 - val_loss: 0.7946 - val_accuracy: 0.9386
# Epoch 135/150
# 38/38 [==============================] - 0s 13ms/step - loss: 0.8840 - accuracy: 0.8945 - val_loss: 0.7789 - val_accuracy: 0.9649
# Epoch 136/150
# 38/38 [==============================] - 0s 12ms/step - loss: 0.8436 - accuracy: 0.8945 - val_loss: 0.7672 - val_accuracy: 0.9474
# Epoch 137/150
# 38/38 [==============================] - 0s 11ms/step - loss: 0.8847 - accuracy: 0.9011 - val_loss: 0.7480 - val_accuracy: 0.9737
# Epoch 138/150
# 38/38 [==============================] - 0s 11ms/step - loss: 0.8737 - accuracy: 0.8923 - val_loss: 0.7300 - val_accuracy: 0.9649
# Epoch 139/150
# 38/38 [==============================] - 0s 12ms/step - loss: 0.8580 - accuracy: 0.9055 - val_loss: 0.7825 - val_accuracy: 0.9298
# Epoch 140/150
# 38/38 [==============================] - 0s 13ms/step - loss: 0.8812 - accuracy: 0.9055 - val_loss: 0.7493 - val_accuracy: 0.9561
# Epoch 141/150
# 38/38 [==============================] - 1s 13ms/step - loss: 0.8384 - accuracy: 0.9011 - val_loss: 1.1158 - val_accuracy: 0.7281
# Epoch 142/150
# 38/38 [==============================] - 0s 13ms/step - loss: 0.8352 - accuracy: 0.9121 - val_loss: 0.7019 - val_accuracy: 0.9649
# Epoch 143/150
# 38/38 [==============================] - 1s 13ms/step - loss: 0.8694 - accuracy: 0.8791 - val_loss: 0.8956 - val_accuracy: 0.8509
# Epoch 144/150
# 38/38 [==============================] - 0s 12ms/step - loss: 0.8826 - accuracy: 0.8769 - val_loss: 0.7363 - val_accuracy: 0.9561
# Epoch 145/150
# 38/38 [==============================] - 0s 13ms/step - loss: 0.8741 - accuracy: 0.8813 - val_loss: 0.7384 - val_accuracy: 0.9737
# Epoch 146/150
# 38/38 [==============================] - 0s 13ms/step - loss: 0.8954 - accuracy: 0.8725 - val_loss: 1.0395 - val_accuracy: 0.8070
# Epoch 147/150
# 38/38 [==============================] - 1s 13ms/step - loss: 0.8411 - accuracy: 0.9209 - val_loss: 0.8681 - val_accuracy: 0.8684
# Epoch 148/150
# 38/38 [==============================] - 0s 12ms/step - loss: 0.8537 - accuracy: 0.9077 - val_loss: 0.7917 - val_accuracy: 0.9386
# Epoch 149/150
# 38/38 [==============================] - 0s 12ms/step - loss: 0.8741 - accuracy: 0.8923 - val_loss: 0.7281 - val_accuracy: 0.9649
# Epoch 150/150
# 38/38 [==============================] - 0s 12ms/step - loss: 0.7872 - accuracy: 0.9275 - val_loss: 0.7350 - val_accuracy: 0.9474
# 4/4 [==============================] - 0s 6ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96        71
#            1       0.91      0.95      0.93        43
#
#     accuracy                           0.95       114
#    macro avg       0.94      0.95      0.94       114
# weighted avg       0.95      0.95      0.95       114
#
# Accuracy on the test Step: 0.9473684210526315
